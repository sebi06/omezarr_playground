# %%
import logging
from ome_zarr_utils import (
    convert_czi2hcs_omezarr,
    convert_czi2hcs_ngff,
    omezarr_package,
    setup_logging,
)
import ngff_zarr as nz
from pathlib import Path

# %%
# ========== Configuration Parameters ==========
# Toggle to display the result in napari viewer (requires napari installation)
show_napari: bool = True

# Backend library selection: OME_ZARR (ome-zarr-py) or NGFF_ZARR (ngff-zarr)
ome_package = omezarr_package.NGFF_ZARR

# Use absolute path to external test data
filepath: str = r"F:\Github\omezarr_playground\data\WP96_4Pos_B4-10_DAPI.czi"

# define plate name for HCS metadata
plate_name: str = "Test_Plate_001"

# ========== Setup Logging ==========
czi_path = Path(filepath)
log_file_path = czi_path.parent / f"{czi_path.stem}_conversion.log"

# Configure logging explicitly
setup_logging(str(log_file_path))
logger = logging.getLogger(__name__)

# %%
logger.info(f"Converting CZI to HCS-ZARR format using {ome_package.name}...")

if ome_package == omezarr_package.OME_ZARR:
    # Convert using ome-zarr-py backend
    zarr_output_path = convert_czi2hcs_omezarr(filepath, overwrite=True)

elif ome_package == omezarr_package.NGFF_ZARR:
    # Convert using ngff-zarr backend
    zarr_output_path = convert_czi2hcs_ngff(filepath, plate_name=plate_name, overwrite=True)
else:
    raise ValueError(f"Unsupported ome_package: {ome_package}")

logger.info(f"✓ Converted to OME-ZARR HCS format at: {zarr_output_path}")
# Out:
# 2025-11-25 19:50:25,687 - __main__ - INFO - Converting CZI to HCS-ZARR format using NGFF_ZARR...
# 2025-11-25 19:50:25,688 - ome_zarr_utils - INFO - ================================================================================
# 2025-11-25 19:50:25,689 - ome_zarr_utils - INFO - CZI to HCS OME-ZARR Conversion Started (NGFF-ZARR format)
# 2025-11-25 19:50:25,689 - ome_zarr_utils - INFO - ================================================================================
# 2025-11-25 19:50:25,690 - ome_zarr_utils - INFO - Input CZI file: F:\Github\omezarr_playground\data\WP96_4Pos_B4-10_DAPI.czi
# 2025-11-25 19:50:25,690 - ome_zarr_utils - INFO - Plate name: Test_Plate_001
# 2025-11-25 19:50:25,691 - ome_zarr_utils - INFO - Removing existing file/directory: F:\Github\omezarr_playground\data\WP96_4Pos_B4-10_DAPI_HCSplate.ome.zarr
# 2025-11-25 19:50:26,371 - ome_zarr_utils - INFO - File removed successfully
# Reading 2D planes: 0 2Dplanes [00:00, ? 2Dplanes/s]
# 2025-11-25 19:50:26,668 - root - INFO - HCS plate structure created at F:\Github\omezarr_playground\data\WP96_4Pos_B4-10_DAPI_HCSplate.ome.zarr
# 2025-11-25 19:50:26,669 - root - INFO - Plate: Test_Plate_001
# 2025-11-25 19:50:26,670 - root - INFO - Wells: 7
# 2025-11-25 19:50:26,670 - root - INFO - Rows: 1, Columns: 7
# 2025-11-25 19:50:26,677 - root - INFO - HCS plate structure created at F:\Github\omezarr_playground\data\WP96_4Pos_B4-10_DAPI_HCSplate.ome.zarr
# 2025-11-25 19:50:26,678 - root - INFO - Plate: Test_Plate_001
# 2025-11-25 19:50:26,679 - root - INFO - Wells: 7
# 2025-11-25 19:50:26,679 - root - INFO - Rows: 1, Columns: 7
# 2025-11-25 19:50:26,680 - ome_zarr_utils - INFO - Creating WellID: B4 Row: B, Column: 4
# 2025-11-25 19:50:26,680 - ome_zarr_utils - INFO - Writing Well: B/4, Field: 0, Scene Index: 0
# 2025-11-25 19:50:27,393 - root - INFO - Written field 0 to well B/4 in HCS plate
# 2025-11-25 19:50:27,394 - ome_zarr_utils - INFO - Writing Well: B/4, Field: 1, Scene Index: 1
# 2025-11-25 19:50:27,513 - root - INFO - Written field 1 to well B/4 in HCS plate
# 2025-11-25 19:50:27,514 - ome_zarr_utils - INFO - Writing Well: B/4, Field: 2, Scene Index: 2
# 2025-11-25 19:50:27,625 - root - INFO - Written field 2 to well B/4 in HCS plate
# 2025-11-25 19:50:27,626 - ome_zarr_utils - INFO - Writing Well: B/4, Field: 3, Scene Index: 3
# 2025-11-25 19:50:27,745 - root - INFO - Written field 3 to well B/4 in HCS plate
# 2025-11-25 19:50:27,746 - ome_zarr_utils - INFO - Creating WellID: B5 Row: B, Column: 5
# 2025-11-25 19:50:27,747 - ome_zarr_utils - INFO - Writing Well: B/5, Field: 0, Scene Index: 4
# 2025-11-25 19:50:27,848 - root - INFO - Written field 0 to well B/5 in HCS plate
# 2025-11-25 19:50:27,848 - ome_zarr_utils - INFO - Writing Well: B/5, Field: 1, Scene Index: 5
# 2025-11-25 19:50:27,953 - root - INFO - Written field 1 to well B/5 in HCS plate
# 2025-11-25 19:50:27,954 - ome_zarr_utils - INFO - Writing Well: B/5, Field: 2, Scene Index: 6
# 2025-11-25 19:50:28,057 - root - INFO - Written field 2 to well B/5 in HCS plate
# 2025-11-25 19:50:28,058 - ome_zarr_utils - INFO - Writing Well: B/5, Field: 3, Scene Index: 7
# 2025-11-25 19:50:28,163 - root - INFO - Written field 3 to well B/5 in HCS plate
# 2025-11-25 19:50:28,164 - ome_zarr_utils - INFO - Creating WellID: B6 Row: B, Column: 6
# 2025-11-25 19:50:28,164 - ome_zarr_utils - INFO - Writing Well: B/6, Field: 0, Scene Index: 8
# 2025-11-25 19:50:28,265 - root - INFO - Written field 0 to well B/6 in HCS plate
# 2025-11-25 19:50:28,266 - ome_zarr_utils - INFO - Writing Well: B/6, Field: 1, Scene Index: 9
# 2025-11-25 19:50:28,367 - root - INFO - Written field 1 to well B/6 in HCS plate
# 2025-11-25 19:50:28,367 - ome_zarr_utils - INFO - Writing Well: B/6, Field: 2, Scene Index: 10
# 2025-11-25 19:50:28,472 - root - INFO - Written field 2 to well B/6 in HCS plate
# 2025-11-25 19:50:28,473 - ome_zarr_utils - INFO - Writing Well: B/6, Field: 3, Scene Index: 11
# 2025-11-25 19:50:28,570 - root - INFO - Written field 3 to well B/6 in HCS plate
# 2025-11-25 19:50:28,571 - ome_zarr_utils - INFO - Creating WellID: B7 Row: B, Column: 7
# 2025-11-25 19:50:28,571 - ome_zarr_utils - INFO - Writing Well: B/7, Field: 0, Scene Index: 12
# 2025-11-25 19:50:28,681 - root - INFO - Written field 0 to well B/7 in HCS plate
# 2025-11-25 19:50:28,682 - ome_zarr_utils - INFO - Writing Well: B/7, Field: 1, Scene Index: 13
# 2025-11-25 19:50:28,794 - root - INFO - Written field 1 to well B/7 in HCS plate
# 2025-11-25 19:50:28,794 - ome_zarr_utils - INFO - Writing Well: B/7, Field: 2, Scene Index: 14
# 2025-11-25 19:50:28,898 - root - INFO - Written field 2 to well B/7 in HCS plate
# 2025-11-25 19:50:28,898 - ome_zarr_utils - INFO - Writing Well: B/7, Field: 3, Scene Index: 15
# 2025-11-25 19:50:29,015 - root - INFO - Written field 3 to well B/7 in HCS plate
# 2025-11-25 19:50:29,016 - ome_zarr_utils - INFO - Creating WellID: B8 Row: B, Column: 8
# 2025-11-25 19:50:29,016 - ome_zarr_utils - INFO - Writing Well: B/8, Field: 0, Scene Index: 16
# 2025-11-25 19:50:29,125 - root - INFO - Written field 0 to well B/8 in HCS plate
# 2025-11-25 19:50:29,125 - ome_zarr_utils - INFO - Writing Well: B/8, Field: 1, Scene Index: 17
# 2025-11-25 19:50:29,230 - root - INFO - Written field 1 to well B/8 in HCS plate
# 2025-11-25 19:50:29,231 - ome_zarr_utils - INFO - Writing Well: B/8, Field: 2, Scene Index: 18
# 2025-11-25 19:50:29,330 - root - INFO - Written field 2 to well B/8 in HCS plate
# 2025-11-25 19:50:29,331 - ome_zarr_utils - INFO - Writing Well: B/8, Field: 3, Scene Index: 19
# 2025-11-25 19:50:29,433 - root - INFO - Written field 3 to well B/8 in HCS plate
# 2025-11-25 19:50:29,434 - ome_zarr_utils - INFO - Creating WellID: B9 Row: B, Column: 9
# 2025-11-25 19:50:29,434 - ome_zarr_utils - INFO - Writing Well: B/9, Field: 0, Scene Index: 20
# 2025-11-25 19:50:29,532 - root - INFO - Written field 0 to well B/9 in HCS plate
# 2025-11-25 19:50:29,533 - ome_zarr_utils - INFO - Writing Well: B/9, Field: 1, Scene Index: 21
# 2025-11-25 19:50:29,632 - root - INFO - Written field 1 to well B/9 in HCS plate
# 2025-11-25 19:50:29,633 - ome_zarr_utils - INFO - Writing Well: B/9, Field: 2, Scene Index: 22
# 2025-11-25 19:50:29,739 - root - INFO - Written field 2 to well B/9 in HCS plate
# 2025-11-25 19:50:29,740 - ome_zarr_utils - INFO - Writing Well: B/9, Field: 3, Scene Index: 23
# 2025-11-25 19:50:29,840 - root - INFO - Written field 3 to well B/9 in HCS plate
# 2025-11-25 19:50:29,840 - ome_zarr_utils - INFO - Creating WellID: B10 Row: B, Column: 10
# 2025-11-25 19:50:29,841 - ome_zarr_utils - INFO - Writing Well: B/10, Field: 0, Scene Index: 24
# 2025-11-25 19:50:29,942 - root - INFO - Written field 0 to well B/10 in HCS plate
# 2025-11-25 19:50:29,943 - ome_zarr_utils - INFO - Writing Well: B/10, Field: 1, Scene Index: 25
# 2025-11-25 19:50:30,040 - root - INFO - Written field 1 to well B/10 in HCS plate
# 2025-11-25 19:50:30,041 - ome_zarr_utils - INFO - Writing Well: B/10, Field: 2, Scene Index: 26
# 2025-11-25 19:50:30,146 - root - INFO - Written field 2 to well B/10 in HCS plate
# 2025-11-25 19:50:30,147 - ome_zarr_utils - INFO - Writing Well: B/10, Field: 3, Scene Index: 27
# 2025-11-25 19:50:30,262 - root - INFO - Written field 3 to well B/10 in HCS plate
# 2025-11-25 19:50:30,262 - ome_zarr_utils - INFO - ================================================================================
# 2025-11-25 19:50:30,263 - ome_zarr_utils - INFO - Conversion completed successfully!
# 2025-11-25 19:50:30,263 - ome_zarr_utils - INFO - Output HCS OME-ZARR file: F:\Github\omezarr_playground\data\WP96_4Pos_B4-10_DAPI_HCSplate.ome.zarr
# 2025-11-25 19:50:30,264 - ome_zarr_utils - INFO - ================================================================================
# 2025-11-25 19:50:30,268 - __main__ - INFO - ✓ Converted to OME-ZARR HCS format at: F:\Github\omezarr_playground\data\WP96_4Pos_B4-10_DAPI_HCSplate.ome.zarr

# %%
# Validate the HCS-ZARR file against OME-NGFF specification
# This ensures proper metadata structure for multi-well plate data

logger.info("Validating created HCS-ZARR file against schema...")
zarr_output_path = nz.from_hcs_zarr(zarr_output_path, validate=True)
logger.info("✓ Validation successful - HCS metadata conforms to specification.")
# Out:
# 2025-11-25 19:50:40,160 - __main__ - INFO - Validating created HCS-ZARR file against schema...
# 2025-11-25 19:50:41,658 - __main__ - INFO - ✓ Validation successful - HCS metadata conforms to specification.
